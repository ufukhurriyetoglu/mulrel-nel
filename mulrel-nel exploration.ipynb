# %%
import pandas as pd

# %%
person_names = []
with open("data/basic_data/p_e_m_data/persons.txt", "r") as f: 
    person_names = f.read().split()

# %%
person_names
# Out:
# ['Abraham',
#  'Lincoln',
#  'Aristotle',
#  'Ayn',
#  'Rand',
#  'Alain',
#  'Connes',
#  'Allan',
#  'Dwan',
#  'Andre',
#  'Agassi',
#  'Aldous',
#  'Huxley',
#  'Andrei',
#  'Tarkovsky',
#  'Arthur',
#  'Schopenhauer',
#  'Albert',
#  'Sidney',
#  'Johnston',
#  'Albert',
#  'Einstein',
#  'Alexander',
#  'the',
#  'Great',
#  'Alfred',
#  'Korzybski',
#  'Alfred',
#  'Hitchcock',
#  'Attila',
#  'Alfred',
#  'Nobel',
#  'Alexander',
#  'Graham',
#  'Bell',
#  'Andy',
#  'Warhol',
#  'Alp',
#  'Arslan',
#  'Akira',
#  'Kurosawa',
#  'A.',
#  'E.',
#  'van',
#  'Vogt',
#  'Anna',
#  'Kournikova',
#  'Alfons',
#  'Maria',
#  'Jakob',
#  'Arne',
#  'Kaijser',
#  'Andrey',
#  'Markov',
#  'A.',
#  'A.',
#  'Milne',
#  'Alvin',
#  'Toffler',
#  'Albert',
#  'Speer',
#  'Ada',
#  'Lovelace',
#  'August',
#  'Derleth',
#  'Albert',
#  'Camus',
#  'Agatha',
#  'Christie',
#  'Allen',
#  'Ginsberg',
#  'Anatoly',
#  'Karpov',
#  'Aristophanes',
#  'Albert',
#  'Schweitzer',
#  'Alexis',
# ...

# %%
# read the AIDA dataset

with open("data/basic_data/test_datasets/AIDA/aida_train.txt", "r") as aida_train_fp:
    aida_train = aida_train_fp.read().splitlines()

# %%
aida_train[:20]
# Out:
# ['-DOCSTART- (1 EU)',
#  'EU\tB\tEU\t--NME--',
#  'rejects',
#  'German\tB\tGerman\tGermany\thttp://en.wikipedia.org/wiki/Germany\t11867\t/m/0345h',
#  'call',
#  'to',
#  'boycott',
#  'British\tB\tBritish\tUnited_Kingdom\thttp://en.wikipedia.org/wiki/United_Kingdom\t31717\t/m/07ssc',
#  'lamb',
#  '.',
#  '',
#  'Peter\tB\tPeter Blackburn\t--NME--',
#  'Blackburn\tI\tPeter Blackburn\t--NME--',
#  '',
#  'BRUSSELS\tB\tBRUSSELS\tBrussels\thttp://en.wikipedia.org/wiki/Brussels\t3708\t/m/0177z',
#  '1996-08-22',
#  '',
#  'The',
#  'European\tB\tEuropean Commission\tEuropean_Commission\thttp://en.wikipedia.org/wiki/European_Commission\t9974\t/m/02q9k',
#  'Commission\tI\tEuropean Commission\tEuropean_Commission\thttp://en.wikipedia.org/wiki/European_Commission\t9974\t/m/02q9k']
